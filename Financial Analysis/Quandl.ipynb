# %% [markdown]
# # Quandl

# %% [markdown]
# Quandl is a great source to pull up the best datasets using

# %%
import quandl

# %%
import matplotlib.pyplot as plt

# %%
quandl.ApiConfig.api_key = 'z8-YSTp-2fw9fba_4HZE'
my_data = quandl.get_table('SMA/FBD', date = '2014-1-1',brand_ticker='MCD,GM,PEP')

# %%
my_data
# Out:
#      brand_ticker            page_id             sector           geography  \
# None
# 0             MCD       100023357865  Restaurant & Cafe            Thailand
# 1              GM    100145153364543         Automotive         Middle East
# 2             PEP    100201000112904      Food/Beverage             Finland
# 3             PEP    100473740084971      Food/Beverage             Vietnam
# 4              GM    100580349985990         Automotive               India
# 5             MCD    100751049971141  Restaurant & Cafe            Slovenia
# 6             PEP        10098929349      Food/Beverage      United Kingdom
# 7             PEP        10139643057      Food/Beverage       United States
# 8             MCD       101428044501        Non Profits      United Kingdom
# 9             MCD  10150097174480584  Restaurant & Cafe           Worldwide
# 10            PEP       101658103787      Food/Beverage              Mexico
# ...

# %%
plt.figure(figsize=(12,7))
plt.plot(my_data['new_fans'])
plt.title('New Fans')
plt.show()

# %% [markdown]
# ### Make a time-series call
#
# This call gets the WTI Crude Oil Price, which has a Quandl Code of EIA/PET_RWTC_D from the US Department of Energy dataset

# %%
data = quandl.get("EIA/PET_RWTC_D")

# %%
data.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %% [markdown]
# #### Change formats
#
# You can get the same data in a NumPy array:

# %%
data = quandl.get("EIA/PET_RWTC_D", returns = 'numpy')
data
# Out:
# rec.array([('1986-01-02T00:00:00.000000000', 25.56),
#            ('1986-01-03T00:00:00.000000000', 26.  ),
#            ('1986-01-06T00:00:00.000000000', 26.53), ...,
#            ('2018-12-28T00:00:00.000000000', 45.15),
#            ('2019-01-02T00:00:00.000000000', 46.31),
#            ('2019-01-03T00:00:00.000000000', 46.92)],
#           dtype=[('Date', '<M8[ns]'), ('Value', '<f8')])

# %%
data = quandl.get("FRED/GDP", start_date="2001-12-31", end_date="2005-12-31")
data
# Out:
#                 Value
# Date
# 2002-01-01  10788.952
# 2002-04-01  10893.207
# 2002-07-01  10992.051
# 2002-10-01  11071.463
# 2003-01-01  11183.507
# 2003-04-01  11312.875
# 2003-07-01  11567.326
# 2003-10-01  11769.275
# 2004-01-01  11920.169
# 2004-04-01  12108.987
# 2004-07-01  12303.340
# 2004-10-01  12522.425
# 2005-01-01  12761.337
# 2005-04-01  12910.022
# 2005-07-01  13142.873
# 2005-10-01  13332.316

# %%
plt.figure(figsize=(12,7))
plt.plot(data['Value'])
plt.title('Stock Value')
plt.show()

# %% [markdown]
# To request specific columns:

# %%
data = quandl.get(["NSE/OIL.1", "WIKI/AAPL.4"])
data.head()
# Out:
#             NSE/OIL - Open  WIKI/AAPL - Close
# Date
# 1980-12-12             NaN              28.75
# 1980-12-15             NaN              27.25
# 1980-12-16             NaN              25.25
# 1980-12-17             NaN              25.87
# 1980-12-18             NaN              26.63

# %% [markdown]
# To request the last 5 rows:

# %%
data = quandl.get("WIKI/AAPL", rows=5)
data
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-03-21          1.0     175.04     175.09    171.26     171.270
# 2018-03-22          1.0     170.00     172.68    168.60     168.845
# 2018-03-23          1.0     168.39     169.92    164.94     164.940
# 2018-03-26          1.0     168.07     173.10    166.44     172.770
# 2018-03-27          1.0     173.68     175.15    166.92     168.340
#
#             Adj. Volume
# Date
# 2018-03-21   35247358.0
# 2018-03-22   41051076.0
# 2018-03-23   40248954.0
# ...

# %% [markdown]
# #### Preprocess the data

# %% [markdown]
# To change the sampling frequency:

# %%
data = quandl.get("EIA/PET_RWTC_D", collapse="monthly")
data
# Out:
#             Value
# Date
# 1986-01-31  18.95
# 1986-02-28  13.23
# 1986-03-31  10.25
# 1986-04-30  13.38
# 1986-05-31  14.30
# 1986-06-30  12.80
# 1986-07-31  11.23
# 1986-08-31  15.93
# 1986-09-30  14.70
# 1986-10-31  15.25
# 1986-11-30  15.00
# 1986-12-31  17.93
# 1987-01-31  18.73
# 1987-02-28  16.45
# 1987-03-31  18.82
# 1987-04-30  18.76
# 1987-05-31  19.36
# 1987-06-30  20.22
# 1987-07-31  21.43
# 1987-08-31  19.76
# 1987-09-30  19.62
# 1987-10-31  19.96
# 1987-11-30  18.52
# 1987-12-31  16.74
# 1988-01-31  16.97
# 1988-02-29  15.98
# 1988-03-31  17.09
# 1988-04-30  18.10
# 1988-05-31  17.54
# 1988-06-30  15.20
# ...           ...
# 2016-08-31  44.68
# 2016-09-30  47.72
# 2016-10-31  46.83
# 2016-11-30  49.41
# 2016-12-31  53.75
# 2017-01-31  52.75
# 2017-02-28  54.00
# 2017-03-31  50.54
# 2017-04-30  49.31
# 2017-05-31  48.29
# 2017-06-30  46.02
# 2017-07-31  50.21
# 2017-08-31  47.26
# 2017-09-30  51.67
# 2017-10-31  54.36
# 2017-11-30  57.40
# 2017-12-31  60.46
# ...

# %% [markdown]
# To perform elementary calculations on the data:

# %%
data = quandl.get("FRED/GDP", transformation="rdiff")

# %% [markdown]
# #### Download an entire time-series dataset
#
# An entire time-series dataset's data can be downloaded.
#
# For example, to download the dataset ZEA:

# %%
quandl.bulkdownload("ZEA")

# %% [markdown]
# This call will download an entire time-series dataset as a ZIP file.

# %% [markdown]
# ### de nada!
