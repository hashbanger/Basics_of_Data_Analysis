# %%
import pandas as pd

# %%
df = pd.read_csv('chicago.csv')

# %%
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null object
# Employee Annual Salary    32062 non-null object
# dtypes: object(4)
# memory usage: 1002.0+ KB

# %%
df.dropna(inplace=True)

# %%
df['Department'].nunique()
# Out:
# 35

# %%
df['Department'].count()
# Out:
# 32062

# %% [markdown]
# * We can see that only 35 of the unique values have been repeated as records 32000 times,
#  to save memory space we can convert it as category type value

# %%
df['Department'] = df['Department'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# We can observe that we saved 300 KBs in memory space.

# %%
df['Department'].str.lower().head()
# Out:
# 0         water mgmnt
# 1              police
# 2              police
# 3    general services
# 4         water mgmnt
# Name: Department, dtype: object

# %%
df['Department'].str.title().head()
# Out:
# 0         Water Mgmnt
# 1              Police
# 2              Police
# 3    General Services
# 4         Water Mgmnt
# Name: Department, dtype: object

# %%
df['Department'].str.len().head()
# Out:
# 0    11
# 1     6
# 2     6
# 3    16
# 4    11
# Name: Department, dtype: int64

# %%
df['Department'].str.replace('MGMNT','MANAGEMENT').head()
# Out:
# 0    WATER MANAGEMENT
# 1              POLICE
# 2              POLICE
# 3    GENERAL SERVICES
# 4    WATER MANAGEMENT
# Name: Department, dtype: object

# %%
df['Employee Annual Salary'].dtype
# Out:
# dtype('O')

# %% [markdown]
# We can observe that **Employee Annual Salary** has been parsed as  string (objects) because of the **$** sign at the beginning.

# %%
df['Employee Annual Salary'] = df['Employee Annual Salary'].str.replace('$','').astype('float')

# %%
df['Employee Annual Salary'].dtype
# Out:
# dtype('float64')

# %%
df['Employee Annual Salary'].nlargest(3)
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# Name: Employee Annual Salary, dtype: float64

# %%
mask = df['Position Title'].str.contains("WATER")

# %%
df[mask].head()
# Out:
#                     Name                                 Position Title  \
# 0        AARON,  ELVIA J                               WATER RATE TAKER
# 554   ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671      ANDER,  PERRY A                               WATER CHEMIST II
# 685  ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702    ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
#
#       Department  Employee Annual Salary
# 0    WATER MGMNT                 90744.0
# 554  WATER MGMNT                102440.0
# 671  WATER MGMNT                 82044.0
# 685  WATER MGMNT                109272.0
# 702  WATER MGMNT                102440.0

# %%
df[df['Position Title'].str.lower().str.startswith('water')].head()
# Out:
#                     Name    Position Title   Department  \
# 0        AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT
# 671      ANDER,  PERRY A  WATER CHEMIST II  WATER MGMNT
# 1054    ASHLEY,  KARMA T  WATER CHEMIST II  WATER MGMNT
# 1079   ATKINS,  JOANNA M  WATER CHEMIST II  WATER MGMNT
# 1181  AZEEM,  MOHAMMED A  WATER CHEMIST II  WATER MGMNT
#
#       Employee Annual Salary
# 0                    90744.0
# 671                  82044.0
# 1054                 82044.0
# 1079                 82044.0
# 1181                 53172.0

# %%
df[df['Position Title'].str.lower().str.endswith('ist')].head()
# Out:
#                     Name                        Position Title  \
# 184       AFROZ,  NAYYAR                          PSYCHIATRIST
# 308     ALARCON,  LUIS J            LOAN PROCESSING SPECIALIST
# 422     ALLAIN,  CAROLYN  SENIOR TELECOMMUNICATIONS SPECIALIST
# 472       ALLEN,  ROBERT                             MACHINIST
# 705  ANDERSON,  EDWARD M             SR PROCUREMENT SPECIALIST
#
#                 Department  Employee Annual Salary
# 184                 HEALTH                 99840.0
# 308  COMMUNITY DEVELOPMENT                 81948.0
# 422                   DoIT                 89880.0
# 472            WATER MGMNT                 94328.0
# 705            PROCUREMENT                 91476.0

# %%
st = '  I AM BATMAN  '

# %%
st.lstrip()
# Out:
# 'I AM BATMAN  '

# %%
st.rstrip()
# Out:
# '  I AM BATMAN'

# %%
st.strip()
# Out:
# 'I AM BATMAN'

# %%
df['Position Title'] = df['Position Title'].str.strip()

# %%
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0
# 3                 89880.0
# 4                106836.0

# %%
df.index = df['Name'].str.title().str.strip()

# %%
df.drop('Name', axis = 1, inplace= True)

# %%
df.head()
# Out:
#                                Position Title        Department  \
# Name
# Aaron,  Elvia J              WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M              POLICE OFFICER            POLICE
# Aaron,  Karina                 POLICE OFFICER            POLICE
# Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#                      Employee Annual Salary
# Name
# Aaron,  Elvia J                     90744.0
# Aaron,  Jeffery M                   84450.0
# Aaron,  Karina                      84450.0
# Aaron,  Kimberlei R                 89880.0
# Abad Jr,  Vicente M                106836.0

# %%
df.columns = df.columns.str.strip().str.upper()

# %%
df.head()
# Out:
#                                POSITION TITLE        DEPARTMENT  \
# Name
# Aaron,  Elvia J              WATER RATE TAKER       WATER MGMNT
# Aaron,  Jeffery M              POLICE OFFICER            POLICE
# Aaron,  Karina                 POLICE OFFICER            POLICE
# Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#                      EMPLOYEE ANNUAL SALARY
# Name
# Aaron,  Elvia J                     90744.0
# Aaron,  Jeffery M                   84450.0
# Aaron,  Karina                      84450.0
# Aaron,  Kimberlei R                 89880.0
# Abad Jr,  Vicente M                106836.0

# %%
df.reset_index(inplace= True)

# %%
df.insert(loc = 0, column = 'FIRST NAME', value = df['Name'].str.split(',').str.get(0))

# %%
df.insert(loc = 1, column = 'LAST NAME', value = df['Name'].str.split(',').str.get(1).str.strip().str.split(" ").str.get(0))

# %%
df.head()
# Out:
#   FIRST NAME  LAST NAME                 Name            POSITION TITLE  \
# 0      Aaron      Elvia      Aaron,  Elvia J          WATER RATE TAKER
# 1      Aaron    Jeffery    Aaron,  Jeffery M            POLICE OFFICER
# 2      Aaron     Karina       Aaron,  Karina            POLICE OFFICER
# 3      Aaron  Kimberlei  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER
# 4    Abad Jr    Vicente  Abad Jr,  Vicente M         CIVIL ENGINEER IV
#
#          DEPARTMENT  EMPLOYEE ANNUAL SALARY
# 0       WATER MGMNT                 90744.0
# 1            POLICE                 84450.0
# 2            POLICE                 84450.0
# 3  GENERAL SERVICES                 89880.0
# 4       WATER MGMNT                106836.0

# %% [markdown]
# Alternate for splitting the names and adding to dataframe can be done as:

# %%
df['Name'].str.split(',', expand = True).head()
# Out:
#          0              1
# 0    Aaron        Elvia J
# 1    Aaron      Jeffery M
# 2    Aaron         Karina
# 3    Aaron    Kimberlei R
# 4  Abad Jr      Vicente M

# %% [markdown]
# **expand** parameter returns a dataframe rather thyan a list of list values.

# %%
df.drop('Name',axis  ='columns', inplace = True)

# %%
df.head()
# Out:
#   FIRST NAME  LAST NAME            POSITION TITLE        DEPARTMENT  \
# 0      Aaron      Elvia          WATER RATE TAKER       WATER MGMNT
# 1      Aaron    Jeffery            POLICE OFFICER            POLICE
# 2      Aaron     Karina            POLICE OFFICER            POLICE
# 3      Aaron  Kimberlei  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4    Abad Jr    Vicente         CIVIL ENGINEER IV       WATER MGMNT
#
#    EMPLOYEE ANNUAL SALARY
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0
# 3                 89880.0
# 4                106836.0

# %%
df['POSITION TITLE'].str.split(' ', expand = True).head(20)
# Out:
#                         0             1            2                 3  \
# 0                   WATER          RATE        TAKER              None
# 1                  POLICE       OFFICER         None              None
# 2                  POLICE       OFFICER         None              None
# 3                   CHIEF      CONTRACT    EXPEDITER              None
# 4                   CIVIL      ENGINEER           IV              None
# 5                    ASST            TO          THE          ALDERMAN
# 6                 GENERAL       LABORER            -               DSS
# 7                 TRAFFIC       CONTROL  AIDE-HOURLY              None
# 8                   STAFF          ASST           TO               THE
# 9              ELECTRICAL      MECHANIC         None              None
# 10                   FIRE  ENGINEER-EMT         None              None
# 11                 POLICE       OFFICER         None              None
# 12                 FOSTER   GRANDPARENT         None              None
# 13                  CLERK           III         None              None
# 14           INVESTIGATOR             -         IPRA                II
# 15                 POLICE       OFFICER         None              None
# 16                 POLICE       OFFICER         None              None
# 17            FIREFIGHTER          (PER  ARBITRATORS  AWARD)-PARAMEDIC
# 18                 POLICE       OFFICER         None              None
# 19  FIREFIGHTER/PARAMEDIC          None         None              None
#
#            4     5     6     7     8
# 0       None  None  None  None  None
# 1       None  None  None  None  None
# 2       None  None  None  None  None
# 3       None  None  None  None  None
# 4       None  None  None  None  None
# 5       None  None  None  None  None
# 6       None  None  None  None  None
# 7       None  None  None  None  None
# 8   ALDERMAN  None  None  None  None
# 9       None  None  None  None  None
# 10      None  None  None  None  None
# 11      None  None  None  None  None
# 12      None  None  None  None  None
# 13      None  None  None  None  None
# 14      None  None  None  None  None
# 15      None  None  None  None  None
# 16      None  None  None  None  None
# 17      None  None  None  None  None
# 18      None  None  None  None  None
# 19      None  None  None  None  None

# %%
df['POSITION TITLE'].str.split(' ', expand =True, n = 4)
# Out:
#                            0                     1            2  \
# 0                      WATER                  RATE        TAKER
# 1                     POLICE               OFFICER         None
# 2                     POLICE               OFFICER         None
# 3                      CHIEF              CONTRACT    EXPEDITER
# 4                      CIVIL              ENGINEER           IV
# 5                       ASST                    TO          THE
# 6                    GENERAL               LABORER            -
# 7                    TRAFFIC               CONTROL  AIDE-HOURLY
# 8                      STAFF                  ASST           TO
# 9                 ELECTRICAL              MECHANIC         None
# 10                      FIRE          ENGINEER-EMT         None
# 11                    POLICE               OFFICER         None
# 12                    FOSTER           GRANDPARENT         None
# 13                     CLERK                   III         None
# 14              INVESTIGATOR                     -         IPRA
# 15                    POLICE               OFFICER         None
# 16                    POLICE               OFFICER         None
# 17               FIREFIGHTER                  (PER  ARBITRATORS
# 18                    POLICE               OFFICER         None
# 19     FIREFIGHTER/PARAMEDIC                  None         None
# 20               ENGINEERING            TECHNICIAN           VI
# 21           FIREFIGHTER-EMT                  None         None
# 22                LIEUTENANT                  None         None
# 23                  CROSSING                 GUARD         None
# 24                ELECTRICAL  MECHANIC-AUTO-POLICE          MTR
# 25                     CIVIL              ENGINEER           II
# 26                   GENERAL               LABORER            -
# 27                    FOSTER           GRANDPARENT         None
# 28                    POLICE               OFFICER         None
# 29                 PARAMEDIC                  None         None
# ...                      ...                   ...          ...
# 32032                 GARAGE             ATTENDANT         None
# 32033                 POLICE               OFFICER         None
# 32034                 POLICE               OFFICER         None
# 32035                 POLICE               OFFICER         None
# 32036                GENERAL               LABORER            -
# 32037        FIREFIGHTER-EMT                  None         None
# 32038                LABORER                     -   APPRENTICE
# 32039         LIEUTENANT-EMT                  None         None
# 32040                 POLICE               OFFICER         None
# 32041               CROSSING                 GUARD         None
# 32042                    FRM                    OF   MACHINISTS
# 32043             SANITATION               LABORER         None
# 32044                 POLICE               OFFICER         None
# 32045             ELECTRICAL              MECHANIC         None
# 32046                 SENIOR                PUBLIC  INFORMATION
# 32047                 POLICE               OFFICER         None
# 32048                  LEGAL             SECRETARY         None
# 32049               CROSSING                 GUARD         None
# 32050                   POOL                 MOTOR        TRUCK
# 32051                AIRPORT            OPERATIONS       SUPVSR
# 32052                 POLICE               OFFICER         None
# 32053        FIREFIGHTER-EMT                  None         None
# 32054                 POLICE               OFFICER         None
# 32055                 POLICE               OFFICER         None
# 32056              MACHINIST          (AUTOMOTIVE)         None
# 32057                    FRM                    OF   MACHINISTS
# 32058                 POLICE               OFFICER         None
# 32059                 POLICE               OFFICER         None
# 32060                 POLICE               OFFICER         None
# 32061                  CHIEF                  DATA         BASE
#
#                       3           4
# 0                  None        None
# 1                  None        None
# 2                  None        None
# 3                  None        None
# 4                  None        None
# 5              ALDERMAN        None
# 6                   DSS        None
# 7                  None        None
# 8                   THE    ALDERMAN
# 9                  None        None
# 10                 None        None
# 11                 None        None
# 12                 None        None
# 13                 None        None
# 14                   II        None
# 15                 None        None
# 16                 None        None
# 17     AWARD)-PARAMEDIC        None
# 18                 None        None
# 19                 None        None
# 20                 None        None
# 21                 None        None
# 22                 None        None
# 23                 None        None
# 24                  MNT        None
# 25                 None        None
# 26                  DSS        None
# 27                 None        None
# 28                 None        None
# 29                 None        None
# ...                 ...         ...
# 32032              None        None
# 32033              None        None
# 32034              None        None
# 32035              None        None
# 32036               DSS        None
# 32037              None        None
# 32038              None        None
# 32039              None        None
# 32040              None        None
# 32041              None        None
# 32042                 -  AUTOMOTIVE
# 32043              None        None
# 32044              None        None
# 32045              None        None
# 32046           OFFICER        None
# 32047              None        None
# 32048              None        None
# 32049              None        None
# 32050            DRIVER        None
# 32051                 I        None
# 32052              None        None
# 32053              None        None
# 32054              None        None
# 32055              None        None
# 32056              None        None
# 32057                 -  AUTOMOTIVE
# 32058              None        None
# 32059              None        None
# 32060              None        None
# 32061           ANALYST        None
#
# [32062 rows x 5 columns]
